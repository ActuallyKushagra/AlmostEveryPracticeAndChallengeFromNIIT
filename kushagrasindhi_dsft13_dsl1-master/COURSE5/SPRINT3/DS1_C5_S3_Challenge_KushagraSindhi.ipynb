# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st
import scipy.stats as sts
import warnings
import numpy as np
import seaborn as sns
warnings.filterwarnings('ignore')

# %% [markdown]
# # task 1

# %% [markdown]
# p(female) = 0.46
#
# p(female/parttime) = 0.25
#
# p(parttime) = 0.174
#
# p(parttime + female) = (p(female) * p(female/ parttime) )/ p(parttime)
#
#                      = (0.46 * 0.25) / 0.174
#
#                      = 0.66

# %% [markdown]
# # task 2

# %% [markdown]
# p(noise) = 0.70
#
# p(storage and noise) = 0.56
#
# p(storage/noise) = p(storage and noise) / p(noise)
#
#                  = 0.56 / 0.70
#
#                  = 0.8

# %%
# task 3

df = pd.read_csv('DS1_C5_S3_GamesSales_Data_Challenge.csv')
df
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# 2         Rockstar Games                    5.26             6.21
# 3             Activision                    4.67             6.21
# 4              EA Sports                    1.27             8.64
# ..                   ...                     ...              ...
# 704  Active Gaming Media                    0.00             0.00
# 705           Rain Games                    0.00             0.01
# 706       Kadokawa Games                    0.00             0.00
# 707      Team17 Software                    0.00             0.00
# 708            Team Meat                    0.00             0.00
#
#      Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 0              0.60            3.02            19.39
# 1              0.41            2.44            15.09
# 2              0.21            2.26            13.94
# 3              0.40            2.12            13.40
# 4              0.15            1.73            11.80
# ..              ...             ...              ...
# 704            0.01            0.00             0.01
# 705            0.00            0.00             0.01
# 706            0.01            0.00             0.01
# 707            0.00            0.00             0.01
# 708            0.00            0.00             0.01
#
# [709 rows x 9 columns]

# %%
# task 1.1

sample_without_rep = df.sample(30, random_state = 1, replace = False, ignore_index = True)
sample_without_rep
# Out:
#                                                  Game  Year             Genre  \
# 0                            One Piece: Burning Blood  2018          Fighting
# 1                                            WWE 2K18  2019            Sports
# 2                          Sengoku Basara 4: Sumeragi  2017            Action
# 3   Earth Defense Force 2025.1: The Shadow of New ...  2017           Shooter
# 4                                  This Is The Police  2019        Simulation
# 5                                  Starblood Arena VR  2019           Shooter
# 6                             Battle Garegga Rev.2018  2018          Strategy
# 7                                               Ni-Oh  2019            Action
# 8                         Dragon Age III: Inquisition  2016      Role-Playing
# 9                         Dynasty Warriors 8: Empires  2016              Misc
# 10                       Resident Evil VII: Biohazard  2019            Action
# 11                            Super Stardust Ultra VR  2018           Shooter
# 12                 Dynasty Warriors 8: Xtreme Legends  2016              Misc
# 13           Disney Infinity 2.0: Marvel Super Heroes  2016  Action-Adventure
# 14                     Call of Duty: Infinite Warfare  2018           Shooter
# 15                      Touhou Kobuto V: Burst Battle  2019           Shooter
# 16                                          A Way Out  2020            Action
# 17                    Metal Gear Solid: Ground Zeroes  2016  Action-Adventure
# 18                          Skylanders: SuperChargers  2017  Action-Adventure
# 19                     The Idolmaster: Platinum Stars  2018        Simulation
# 20                                      Ben 10 (2019)  2019            Action
# 21  Teenage Mutant Ninja Turtles: Mutants in Manha...  2018            Action
# 22                                Pillars of Eternity  2019      Role-Playing
# 23                                 Patapon Remastered  2019             Music
# 24                                   Song of the Deep  2018            Action
# 25                                     ClaDun Sengoku  2019            Action
# 26                                    Dragon Quest XI  2019      Role-Playing
# 27          Summer Lesson: Miyamoto Hikari Collection  2019         Adventure
# 28                    Crash Bandicoot N. Sane Trilogy  2019          Platform
# 29                               inFAMOUS: Second Son  2016  Action-Adventure
#
#                          Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0               Namco Bandai Games                    0.21             0.26
# 1                        2K Sports                    0.45             0.67
# 2                           Capcom                    0.00             0.00
# 3                      D3Publisher                    0.00             0.00
# 4                       THQ Nordic                    0.01             0.00
# 5   Sony Interactive Entertainment                    0.04             0.00
# 6                               M2                    0.00             0.00
# 7                       Tecmo Koei                    0.34             0.36
# 8                  Electronic Arts                    1.07             0.80
# 9                       Tecmo Koei                    0.07             0.07
# 10                          Capcom                    0.88             1.56
# 11  Sony Interactive Entertainment                    0.00             0.02
# 12                      Tecmo Koei                    0.09             0.12
# 13      Disney Interactive Studios                    0.37             0.25
# 14                      Activision                    3.11             3.83
# 15                     NIS America                    0.02             0.00
# 16                 Electronic Arts                    0.23             0.16
# 17    Konami Digital Entertainment                    0.36             0.50
# 18                      Activision                    0.29             0.09
# 19              Namco Bandai Games                    0.00             0.00
# 20                  Outright Games                    0.04             0.00
# 21                      Activision                    0.07             0.03
# 22            Paradox InteractiveÊ                    0.11             0.02
# 23  Sony Interactive Entertainment                    0.00             0.00
# 24                 Insomniac Games                    0.12             0.00
# 25                     NIS America                    0.02             0.00
# 26                     Square Enix                    0.29             0.22
# 27              Namco Bandai Games                    0.00             0.00
# 28                      Activision                    1.09             2.92
# 29     Sony Computer Entertainment                    1.35             1.09
#
#     Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 0             0.09            0.09             0.65
# 1             0.00            0.22             1.33
# 2             0.05            0.00             0.05
# 3             0.11            0.00             0.11
# 4             0.00            0.00             0.02
# 5             0.00            0.01             0.05
# 6             0.01            0.00             0.01
# 7             0.20            0.14             1.03
# 8             0.08            0.38             2.34
# 9             0.04            0.03             0.21
# 10            0.41            0.46             3.31
# 11            0.00            0.00             0.02
# 12            0.06            0.04             0.31
# 13            0.00            0.13             0.75
# 14            0.19            1.36             8.48
# 15            0.00            0.00             0.03
# 16            0.00            0.08             0.48
# 17            0.17            0.17             1.20
# 18            0.00            0.08             0.45
# 19            0.11            0.00             0.11
# 20            0.00            0.01             0.05
# 21            0.00            0.02             0.12
# 22            0.00            0.03             0.16
# 23            0.02            0.00             0.02
# 24            0.00            0.03             0.15
# 25            0.00            0.00             0.03
# 26            1.43            0.10             2.04
# 27            0.01            0.00             0.01
# 28            0.07            0.74             4.83
# 29            0.07            0.50             3.01

# %%
# task 1.2

sample_with_rep = df.sample(30, random_state = 1, replace = True, ignore_index = True)
sample_with_rep
# Out:
#                                                  Game  Year             Genre  \
# 0                                           Far Cry 5  2020            Action
# 1                                   Tales of Zestiria  2017      Role-Playing
# 2                             Need for Speed: Payback  2019            Racing
# 3   God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018            Action
# 4                            Injustice: Gods Among Us  2015          Fighting
# 5                                         LEGO Worlds  2019              Misc
# 6                                          Dungeons 3  2019          Strategy
# 7                     Dead or Alive Xtreme 3: Fortune  2018            Sports
# 8                                              MXGP 2  2018            Racing
# 9                                        Yooka-Laylee  2019          Platform
# 10                           The LEGO Movie Videogame  2016  Action-Adventure
# 11                        Saint Seiya: Soldiers' Soul  2017          Fighting
# 12                                             Vampyr  2020      Role-Playing
# 13           MXGP 3: The Official Motocross Videogame  2019            Racing
# 14  Earth Defense Force 4.1: The Shadow of New Des...  2017           Shooter
# 15                                 Resident Evil Zero  2018  Action-Adventure
# 16     The Walking Dead: A Telltale Series Collection  2019         Adventure
# 17                          FlatOut 4: Total Insanity  2019            Racing
# 18                          Valentino Rossi: The Game  2018            Racing
# 19                                         That's You  2019             Party
# 20               Yonder: The Cloud Catcher Chronicles  2019            Action
# 21                                             NHL 17  2018            Sports
# 22                          Legend of Kay Anniversary  2017            Action
# 23                                              WRC 6  2018            Racing
# 24                                         Until Dawn  2017         Adventure
# 25                                              Steep  2018            Sports
# 26                              Samurai Warriors 4-II  2017            Action
# 27                                   Spider-Man (PS4)  2020  Action-Adventure
# 28                  Dead Island Definitive Collection  2018            Action
# 29                                       Black Mirror  2019         Adventure
#
#                                  Publisher  North_America_Sales_M$  \
# 0                                  Ubisoft                    1.44
# 1                       Namco Bandai Games                    0.18
# 2                          Electronic Arts                    0.62
# 3                       Namco Bandai Games                    0.00
# 4   Warner Bros. Interactive Entertainment                    0.46
# 5   Warner Bros. Interactive Entertainment                    0.21
# 6                            Kalypso Media                    0.03
# 7                               Tecmo Koei                    0.00
# 8                         Milestone S.r.l.                    0.05
# 9                                 Sold Out                    0.09
# 10  Warner Bros. Interactive Entertainment                    0.26
# 11                      Namco Bandai Games                    0.00
# 12                  Focus Home Interactive                    0.12
# 13                               Milestone                    0.06
# 14                                   PQube                    0.05
# 15                                  Capcom                    0.07
# 16  Warner Bros. Interactive Entertainment                    0.06
# 17                      Bigben Interactive                    0.01
# 18                      Namco Bandai Games                    0.05
# 19          Sony Interactive Entertainment                    0.04
# 20                       CokeM Interactive                    0.03
# 21                               EA Sports                    0.32
# 22                            Nordic Games                    0.00
# 23                                   PQube                    0.03
# 24             Sony Computer Entertainment                    0.62
# 25                                 Ubisoft                    0.23
# 26                              Tecmo Koei                    0.04
# 27          Sony Interactive Entertainment                    3.64
# 28                             Deep Silver                    0.09
# 29                              THQ Nordic                    0.04
#
#     Europe_Sales_M$  Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 0              1.73            0.15            0.62             3.95
# 1              0.16            0.04            0.07             0.45
# 2              1.18            0.04            0.34             2.18
# 3              0.00            0.02            0.00             0.02
# 4              0.35            0.00            0.17             0.98
# 5              0.72            0.04            0.17             1.14
# 6              0.00            0.00            0.01             0.04
# 7              0.00            0.06            0.00             0.06
# 8              0.06            0.00            0.02             0.14
# 9              0.16            0.00            0.05             0.29
# 10             0.32            0.01            0.11             0.71
# 11             0.21            0.05            0.04             0.30
# 12             0.19            0.00            0.06             0.37
# 13             0.08            0.00            0.03             0.17
# 14             0.02            0.00            0.01             0.08
# 15             0.18            0.07            0.05             0.37
# 16             0.00            0.00            0.01             0.07
# 17             0.00            0.00            0.00             0.02
# 18             0.05            0.00            0.02             0.13
# 19             0.00            0.00            0.01             0.04
# 20             0.00            0.00            0.01             0.04
# 21             0.11            0.00            0.09             0.52
# 22             0.06            0.00            0.01             0.07
# 23             0.02            0.01            0.01             0.08
# 24             0.92            0.06            0.30             1.90
# 25             0.60            0.02            0.15             1.01
# 26             0.02            0.07            0.01             0.13
# 27             3.39            0.32            1.41             8.76
# 28             0.08            0.03            0.03             0.23
# 29             0.00            0.00            0.01             0.05

# %%
# task 1.3

j = np.arange(0, len(df), 5)
sys_sample = df.iloc[j]
sys_sample
# Out:
#                                                   Game  Year      Genre  \
# 0                                   Grand Theft Auto V  2016     Action
# 5                                              FIFA 17  2018     Sports
# 10                                             FIFA 16  2017     Sports
# 15                                           MineCraft  2016       Misc
# 20              Uncharted: The Nathan Drake Collection  2017     Action
# ..                                                 ...   ...        ...
# 685  Kono Subarashii Sekai ni Shukufuku o! Kono Yok...  2019  Adventure
# 690                                     Zombie Vikings  2018     Action
# 695                                LocoRoco Remastered  2019   Platform
# 700        Date-A-Live Twin Edition: Rio Reincarnation  2019  Adventure
# 705                                          Teslagrad  2016   Platform
#
#                           Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0                    Rockstar Games                    6.06             9.71
# 5                   Electronic Arts                    1.26             7.95
# 10                        EA Sports                    1.15             5.77
# 15      Sony Computer Entertainment                    1.89             3.13
# 20      Sony Computer Entertainment                    2.55             2.11
# ..                              ...                     ...              ...
# 685                             5pb                    0.00             0.00
# 690               Rising Star Games                    0.00             0.01
# 695  Sony Interactive Entertainment                    0.00             0.00
# 700                   Compile Heart                    0.00             0.00
# 705                      Rain Games                    0.00             0.01
#
#      Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 0              0.60            3.02            19.39
# 5              0.12            1.61            10.94
# 10             0.07            1.23             8.22
# 15             0.35            0.96             6.33
# 20             0.10            0.94             5.70
# ..              ...             ...              ...
# 685            0.01            0.00             0.01
# 690            0.00            0.00             0.01
# 695            0.01            0.00             0.01
# 700            0.01            0.00             0.01
# 705            0.00            0.00             0.01
#
# [142 rows x 9 columns]

# %%
# task 1.4 a

strat_sample = pd.DataFrame()
grp = df.groupby('Year')
grpname = df['Year'].unique()

for i in grpname:
    dat = grp.get_group(i)
    sample = dat.sample(30, replace = True, random_state = 1)
    strat_sample = strat_sample.append(sample, ignore_index = True)
strat_sample
# Out:
#                                Game  Year             Genre  \
# 0                   LEGO The Hobbit  2016  Action-Adventure
# 1                          NBA 2K15  2016            Sports
# 2                    Child of Light  2016      Role-Playing
# 3    Middle-Earth: Shadow of Mordor  2016            Action
# 4                     Omega Quintet  2016      Role-Playing
# ..                              ...   ...               ...
# 175           Skylanders SWAP Force  2015              Misc
# 176                   Madden NFL 25  2015            Sports
# 177           Skylanders SWAP Force  2015              Misc
# 178                     NBA Live 14  2015            Sports
# 179          Angry Birds: Star Wars  2015            Puzzle
#
#                                   Publisher  North_America_Sales_M$  \
# 0    Warner Bros. Interactive Entertainment                    0.14
# 1                                 2K Sports                    1.49
# 2                                   Ubisoft                    0.00
# 3    Warner Bros. Interactive Entertainment                    1.03
# 4                             Compile Heart                    0.00
# ..                                      ...                     ...
# 175                              Activision                    0.23
# 176                               EA Sports                    0.64
# 177                              Activision                    0.23
# 178                               EA Sports                    0.17
# 179                              Activision                    0.11
#
#      Europe_Sales_M$  Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 0               0.39            0.00            0.10             0.62
# 1               0.55            0.01            0.44             2.49
# 2               0.01            0.04            0.00             0.05
# 3               1.60            0.05            0.51             3.19
# 4               0.00            0.02            0.00             0.03
# ..               ...             ...             ...              ...
# 175             0.14            0.00            0.08             0.44
# 176             0.15            0.00            0.17             0.96
# 177             0.14            0.00            0.08             0.44
# 178             0.05            0.00            0.05             0.27
# 179             0.09            0.00            0.04             0.23
#
# [180 rows x 9 columns]

# %%
# task 1.4 b

strat_sample = pd.DataFrame()
grp = df.groupby('Genre')
grpname = df['Genre'].unique()

for i in grpname:
    dat = grp.get_group(i)
    sample = dat.sample(30, replace = True, random_state = 1)
    strat_sample = strat_sample.append(sample, ignore_index = True)
strat_sample
# Out:
#                                                   Game  Year         Genre  \
# 0    Dragon Quest Heroes: The World's Tree Woe and ...  2017        Action
# 1                            Unbox: Newbie's Adventure  2019        Action
# 2                                    Attack on Titan 2  2020        Action
# 3                           Vikings: Wolves of Midgard  2019        Action
# 4                  Sengoku Basara: Sanada Yukimura-Den  2018        Action
# ..                                                 ...   ...           ...
# 505                                        Root Letter  2018  Visual Novel
# 506                                    The Silver Case  2019  Visual Novel
# 507                                        Root Letter  2018  Visual Novel
# 508         Konoyo no Hate de Koi o Utau Shoujo: Yu-No  2019  Visual Novel
# 509                                        Chaos;Child  2017  Visual Novel
#
#          Publisher  North_America_Sales_M$  Europe_Sales_M$  Japan_Sales_M$  \
# 0      Square Enix                    0.21             0.14            0.39
# 1      Merge Games                    0.03             0.00            0.00
# 2       Koei Tecmo                    0.09             0.04            0.06
# 3    Kalypso Media                    0.03             0.01            0.00
# 4           Capcom                    0.00             0.00            0.05
# ..             ...                     ...              ...             ...
# 505          PQube                    0.00             0.00            0.03
# 506    NIS America                    0.05             0.00            0.01
# 507          PQube                    0.00             0.00            0.03
# 508            5pb                    0.00             0.00            0.02
# 509          PQube                    0.00             0.00            0.02
#
#      Other_Sales_M$  Global_Sales_M$
# 0              0.07             0.81
# 1              0.01             0.04
# 2              0.03             0.22
# 3              0.01             0.04
# 4              0.00             0.05
# ..              ...              ...
# 505            0.00             0.03
# 506            0.01             0.07
# 507            0.00             0.03
# 508            0.00             0.02
# 509            0.00             0.02
#
# [510 rows x 9 columns]

# %%
# 1.5 a) clustered sampling with year

t = df.groupby('Year')
grp2 = [2018, 2019]
ndf2 = pd.DataFrame()

for i in grp2:
    data2 = t.get_group(i)
    sample2 = data2.sample(20, replace = True, random_state = 1)
    ndf2 = ndf2.append(sample2, ignore_index = True)
    
ndf2
# Out:
#                                                  Game  Year             Genre  \
# 0                Assassin's Creed The Ezio Collection  2018            Action
# 1               Sherlock Holmes: The Devil's Daughter  2018         Adventure
# 2                               Robinson: The Journey  2018  Action-Adventure
# 3                                              ZombiU  2018            Action
# 4                   Touhou Genso Rondo: Bullet Ballet  2018           Shooter
# 5                                       EVE: Valkyrie  2018           Shooter
# 6            Touhou Shinhiroku: Urban Legend in Limbo  2018          Fighting
# 7                                   Werewolves Within  2018              Misc
# 8                                  Resident Evil 5 HD  2018            Action
# 9                                    Killing Floor 2Ê  2018           Shooter
# 10                  Kamen Rider: Battride War Genesis  2018            Action
# 11                                   Street Fighter V  2018          Fighting
# 12                                        Root Letter  2018      Visual Novel
# 13                                       Dishonored 2  2018            Action
# 14  Teenage Mutant Ninja Turtles: Mutants in Manha...  2018            Action
# 15                Sengoku Basara: Sanada Yukimura-Den  2018            Action
# 16                    Dead or Alive Xtreme 3: Fortune  2018            Sports
# 17                           Anima - Gate of Memories  2018            Action
# 18                                      Here They Lie  2018         Adventure
# 19                    Cartoon Network Battle Crashers  2018            Action
# 20                                      Hitman (2016)  2019            Action
# 21        Date-A-Live Twin Edition: Rio Reincarnation  2019         Adventure
# 22                                              WRC 7  2019            Racing
# 23                       Ultimate Marvel vs. Capcom 3  2019          Fighting
# 24     The Walking Dead: A Telltale Series Collection  2019         Adventure
# 25                                        Lost Sphear  2019      Role-Playing
# 26                The Witch and the Hundred Knights 2  2019      Role-Playing
# 27                        theHunter: Call of the Wild  2019           Shooter
# 28                                      Blackguards 2  2019          Strategy
# 29                           Batman: The Enemy Within  2019         Adventure
# 30                                 ATV Drift & Tricks  2019            Racing
# 31                                   Superbeat: Xonic  2019             Music
# 32                                      Gundam Versus  2019            Action
# 33                     One Piece: Unlimited World Red  2019            Action
# 34                                    Has-Been Heroes  2019            Action
# 35                                           WWE 2K18  2019            Sports
# 36                                         Dungeons 3  2019          Strategy
# 37                                           Tekken 7  2019          Fighting
# 38  Blue Reflection: Maboroshi ni Mau - Shoujo no Ken  2019      Role-Playing
# 39                                           Rugby 18  2019            Sports
#
#                                  Publisher  North_America_Sales_M$  \
# 0                                  Ubisoft                    0.14
# 1                       Bigben Interactive                    0.05
# 2           Sony Interactive Entertainment                    0.14
# 3                                  Ubisoft                    0.00
# 4                              NIS America                    0.06
# 5           Sony Interactive Entertainment                    0.11
# 6                               Mediascape                    0.00
# 7                                  Ubisoft                    0.04
# 8                                   Capcom                    0.05
# 9                     Tripwire Interactive                    0.19
# 10                      Namco Bandai Games                    0.00
# 11                                  Capcom                    0.64
# 12                                   PQube                    0.00
# 13                      Bethesda Softworks                    0.62
# 14                              Activision                    0.07
# 15                                  Capcom                    0.00
# 16                              Tecmo Koei                    0.00
# 17                               Avanquest                    0.01
# 18          Sony Interactive Entertainment                    0.00
# 19                           Maximum Games                    0.05
# 20                             Square Enix                    0.24
# 21                           Compile Heart                    0.00
# 22                      Bigben Interactive                    0.06
# 23                                  Capcom                    0.19
# 24  Warner Bros. Interactive Entertainment                    0.06
# 25                             Square Enix                    0.00
# 26                    Nippon Ichi Software                    0.03
# 27                                Astragon                    0.19
# 28                           Kalypso Media                    0.02
# 29                          Telltale Games                    0.05
# 30                            Funbox Media                    0.07
# 31                              PM Studios                    0.02
# 32                      Namco Bandai Games                    0.08
# 33                      Namco Bandai Games                    0.00
# 34                               GameTrust                    0.06
# 35                               2K Sports                    0.45
# 36                           Kalypso Media                    0.03
# 37                      Namco Bandai Games                    0.60
# 38                              Tecmo Koei                    0.07
# 39                              Koch Media                    0.05
#
#     Europe_Sales_M$  Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 0              0.52            0.02            0.12             0.79
# 1              0.00            0.00            0.01             0.06
# 2              0.09            0.00            0.05             0.27
# 3              0.04            0.01            0.01             0.07
# 4              0.00            0.00            0.01             0.07
# 5              0.06            0.00            0.04             0.21
# 6              0.00            0.02            0.00             0.02
# 7              0.00            0.00            0.01             0.05
# 8              0.00            0.01            0.01             0.07
# 9              0.03            0.00            0.05             0.27
# 10             0.00            0.07            0.00             0.07
# 11             0.42            0.12            0.22             1.39
# 12             0.00            0.03            0.00             0.03
# 13             1.02            0.01            0.31             1.97
# 14             0.03            0.00            0.02             0.12
# 15             0.00            0.05            0.00             0.05
# 16             0.00            0.06            0.00             0.06
# 17             0.02            0.00            0.01             0.04
# 18             0.03            0.00            0.01             0.04
# 19             0.00            0.00            0.01             0.06
# 20             0.36            0.06            0.11             0.78
# 21             0.00            0.01            0.00             0.01
# 22             0.00            0.00            0.01             0.07
# 23             0.00            0.02            0.04             0.26
# 24             0.00            0.00            0.01             0.07
# 25             0.00            0.02            0.00             0.02
# 26             0.00            0.03            0.01             0.07
# 27             0.00            0.00            0.04             0.24
# 28             0.00            0.00            0.01             0.03
# 29             0.00            0.00            0.01             0.07
# 30             0.00            0.00            0.02             0.09
# 31             0.00            0.00            0.00             0.02
# 32             0.00            0.18            0.02             0.28
# 33             0.00            0.01            0.00             0.01
# 34             0.00            0.00            0.01             0.07
# 35             0.67            0.00            0.22             1.33
# 36             0.00            0.00            0.01             0.04
# 37             0.72            0.12            0.26             1.70
# 38             0.00            0.06            0.02             0.14
# 39             0.00            0.00            0.01             0.06

# %%
# 1.5 b) clustered sampling with genre

t2 = df.groupby('Genre')
grp2 = ['Action', 'Shooter']
ndf2 = pd.DataFrame()

for i in grp2:
    data2 = t2.get_group(i)
    sample2 = data2.sample(20, replace = True, random_state = 1)
    ndf2 = ndf2.append(sample2, ignore_index = True)
    
ndf2
# Out:
#                                                  Game  Year    Genre  \
# 0   Dragon Quest Heroes: The World's Tree Woe and ...  2017   Action
# 1                           Unbox: Newbie's Adventure  2019   Action
# 2                                   Attack on Titan 2  2020   Action
# 3                          Vikings: Wolves of Midgard  2019   Action
# 4                 Sengoku Basara: Sanada Yukimura-Den  2018   Action
# 5                                    Agents of Mayhem  2019   Action
# 6                               Infamous: First Light  2016   Action
# 7                                          Extinction  2020   Action
# 8                                    Dead by Daylight  2019   Action
# 9                          Sengoku Basara 4: Sumeragi  2017   Action
# 10                                LEGO Jurassic World  2017   Action
# 11                                    The Evil Within  2016   Action
# 12                                        Musou Stars  2019   Action
# 13                    Dragon's Dogma Online: Season 2  2018   Action
# 14                                        Axiom Verge  2019   Action
# 15                                       Earth's Dawn  2018   Action
# 16                            Carmageddon: Max Damage  2018   Action
# 17               Yonder: The Cloud Catcher Chronicles  2019   Action
# 18                                      Saints Row IV  2017   Action
# 19                     RIGS: Mechanized Combat League  2018   Action
# 20                          Homefront: The Revolution  2018  Shooter
# 21                                          Destiny 2  2019  Shooter
# 22                          Tom Clancy's The Division  2018  Shooter
# 23                                      Battlefield 1  2018  Shooter
# 24                      Resident Evil: Umbrella Corps  2018  Shooter
# 25                              Killzone: Shadow Fall  2015  Shooter
# 26                                 Call of Duty: WWII  2019  Shooter
# 27                                            Destiny  2016  Shooter
# 28                                        Prey (2019)  2019  Shooter
# 29                     Bulletstorm: Full Clip Edition  2019  Shooter
# 30                                        Titanfall 2  2018  Shooter
# 31                            Destiny: The Taken King  2017  Shooter
# 32                               Call of Duty: Ghosts  2015  Shooter
# 33                          Until Dawn: Rush of Blood  2018  Shooter
# 34                            Destiny: The Collection  2018  Shooter
# 35                                      Battlefield 4  2015  Shooter
# 36                     Bulletstorm: Full Clip Edition  2019  Shooter
# 37                               Rogue Trooper: Redux  2019  Shooter
# 38                                          Far Cry 4  2016  Shooter
# 39                          Tom Clancy's The Division  2018  Shooter
#
#                                  Publisher  North_America_Sales_M$  \
# 0                              Square Enix                    0.21
# 1                              Merge Games                    0.03
# 2                               Koei Tecmo                    0.09
# 3                            Kalypso Media                    0.03
# 4                                   Capcom                    0.00
# 5                              Deep Silver                    0.08
# 6              Sony Computer Entertainment                    0.00
# 7                            Maximum Games                    0.05
# 8                                505 Games                    0.11
# 9                                   Capcom                    0.00
# 10  Warner Bros. Interactive Entertainment                    0.41
# 11                      Bethesda Softworks                    0.56
# 12                              Tecmo Koei                    0.03
# 13                                  Capcom                    0.00
# 14                          Badland Studio                    0.03
# 15                       Rising Star Games                    0.02
# 16                         Stainless Games                    0.02
# 17                       CokeM Interactive                    0.03
# 18                             Deep Silver                    0.15
# 19          Sony Interactive Entertainment                    0.11
# 20                             Deep Silver                    0.11
# 21                              Activision                    1.92
# 22                                 Ubisoft                    1.49
# 23                         Electronic Arts                    2.20
# 24                                  Capcom                    0.00
# 25             Sony Computer Entertainment                    0.89
# 26                              Activision                    4.67
# 27                              Activision                    2.53
# 28                      Bethesda Softworks                    0.25
# 29                        Gearbox Software                    0.05
# 30                         Electronic Arts                    0.75
# 31                              Activision                    0.97
# 32                              Activision                    1.79
# 33          Sony Interactive Entertainment                    0.50
# 34                              Activision                    0.24
# 35                         Electronic Arts                    1.40
# 36                        Gearbox Software                    0.05
# 37                               Rebellion                    0.01
# 38                                 Ubisoft                    1.18
# 39                                 Ubisoft                    1.49
#
#     Europe_Sales_M$  Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 0              0.14            0.39            0.07             0.81
# 1              0.00            0.00            0.01             0.04
# 2              0.04            0.06            0.03             0.22
# 3              0.01            0.00            0.01             0.04
# 4              0.00            0.05            0.00             0.05
# 5              0.08            0.00            0.03             0.20
# 6              0.03            0.00            0.00             0.03
# 7              0.00            0.00            0.01             0.06
# 8              0.06            0.02            0.04             0.22
# 9              0.00            0.05            0.00             0.05
# 10             0.56            0.02            0.19             1.18
# 11             0.90            0.11            0.28             1.86
# 12             0.00            0.06            0.01             0.10
# 13             0.00            0.03            0.00             0.03
# 14             0.00            0.00            0.01             0.04
# 15             0.00            0.00            0.00             0.02
# 16             0.00            0.00            0.00             0.02
# 17             0.00            0.00            0.01             0.04
# 18             0.18            0.03            0.06             0.42
# 19             0.06            0.02            0.04             0.23
# 20             0.29            0.04            0.07             0.50
# 21             1.44            0.10            0.69             4.14
# 22             2.04            0.16            0.69             4.37
# 23             3.65            0.29            1.12             7.26
# 24             0.00            0.04            0.00             0.04
# 25             1.58            0.08            0.47             3.02
# 26             6.21            0.40            2.12            13.40
# 27             2.13            0.16            0.94             5.76
# 28             0.62            0.02            0.16             1.04
# 29             0.06            0.00            0.02             0.13
# 30             0.62            0.06            0.28             1.72
# 31             0.80            0.05            0.36             2.18
# 32             1.64            0.05            0.69             4.17
# 33             0.21            0.00            0.15             0.85
# 34             0.40            0.02            0.12             0.78
# 35             1.74            0.19            0.62             3.94
# 36             0.06            0.00            0.02             0.13
# 37             0.00            0.00            0.00             0.02
# 38             2.14            0.11            0.63             4.06
# 39             2.04            0.16            0.69             4.37

# %%
# task 2.1 + task 2.2

popdata = df['Global_Sales_M$']
sam10 = popdata.sample(10, replace = True, random_state = 1, ignore_index = True)
sam20 = popdata.sample(20, replace = True, random_state = 1, ignore_index = True)
sam30 = popdata.sample(30, replace = True, random_state = 1, ignore_index = True)
sam40 = popdata.sample(40, replace = True, random_state = 1, ignore_index = True)

popmean = st.mean(popdata)
popmed = st.median(popdata)
popstd = st.stdev(popdata)

sam10mean = st.mean(sam10)
sam10med = st.median(sam10)
sam10std = st.stdev(sam10)

sam20mean = st.mean(sam20)
sam20med = st.median(sam20)
sam20std = st.stdev(sam20)

sam30mean = st.mean(sam30)
sam30med = st.median(sam30)
sam30std = st.stdev(sam30)

sam40mean = st.mean(sam40)
sam40med = st.median(sam40)
sam40std = st.stdev(sam40)

# %%
table = pd.DataFrame({'Population Data': [popmean, popmed, popstd],
                     'Sample Size 10': [sam10mean, sam10med, sam10std],
                     'Sample Size 20': [sam20mean, sam20med, sam20std],
                     'Sample Size 30': [sam30mean, sam30med, sam30std],
                     'Sample Size 40': [sam40mean, sam40med, sam40std]},
                    index = ['Mean', 'Median', 'Standard Deviation'])
table
# Out:
#                     Population Data  Sample Size 10  Sample Size 20  \
# Mean                       0.839803        0.925000        0.575500
# Median                     0.170000        0.370000        0.230000
# Standard Deviation         1.853915        1.263613        0.952274
#
#                     Sample Size 30  Sample Size 40
# Mean                      0.810000        0.650250
# Median                    0.200000        0.155000
# Standard Deviation        1.721006        1.512594

# %%
# task 2.3

plt.figure(figsize=(20, 30))

plt.subplot(5, 2, 1)
sns.distplot(popdata, kde = True, color = 'purple')
plt.title('Population Data')

plt.subplot(5, 2, 2)
sns.boxplot(popdata, color = 'red')
plt.title('Population Data')

plt.subplot(5, 2, 3)
sns.distplot(sam10, kde = True, color = 'purple')
plt.title('Sample Size 10')

plt.subplot(5, 2, 4)
sns.boxplot(sam10, color = 'red')
plt.title('Sample Size 10')

plt.subplot(5, 2, 5)
sns.distplot(sam20, kde = True, color = 'purple')
plt.title('Sample Size 20')

plt.subplot(5, 2, 6)
sns.boxplot(sam20, color = 'red')
plt.title('Sample Size 20')

plt.subplot(5, 2, 7)
sns.distplot(sam30, kde = True, color = 'purple')
plt.title('Sample Size 30')

plt.subplot(5, 2, 8)
sns.boxplot(sam30, color = 'red')
plt.title('Sample Size 30')

plt.subplot(5, 2, 9)
sns.distplot(sam40, kde = True, color = 'purple')
plt.title('Sample Size 40')

plt.subplot(5, 2, 10)
sns.boxplot(sam40, color = 'red')
plt.title('Sample Size 40');

# %% [markdown]
# #### task 2.4
#
# It can be observed that as the sample size grows bigger, it starts to get closer and closer to the population data.
#
#
# Larger samples more closely approximate the population.
#
#
# Comparing the graphs alone for population data and sample data 40, it can be seen that they are closely related, ie, the sample data 40 is almost similar/ same as the population data
