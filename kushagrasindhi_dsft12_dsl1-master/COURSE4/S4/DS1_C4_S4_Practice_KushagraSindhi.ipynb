# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('DS1_C4_S4_Test_Scores_Data_Practice.csv')

# %%
# task 1 All duplicate values after their first occurance

t1dup = data.loc[:, data.columns!='student_id']
t1dup2 = t1dup[t1dup.duplicated(keep = 'first')]
t1dup2
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# 19    ANKYI          Urban  Non-public       6OL        Standard    Male
# 38    ANKYI          Urban  Non-public       ZNS        Standard  Female
# 50    CCAAW       Suburban  Non-public       2B1    Experimental    Male
# 106   CCAAW       Suburban  Non-public       PGK        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2058  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2067  ZOWMK          Urban      Public       Q0E    Experimental    Male
# 2070  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2080  ZOWMK          Urban      Public       QA2        Standard  Female
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
#
#                                  lunch  pretest  posttest
# 4                     Does not qualify     64.0      76.0
# 19                    Does not qualify     64.0      73.0
# 38                    Does not qualify     59.0      69.0
# 50    Qualifies for reduced/free lunch     59.0      74.0
# 106                   Does not qualify     73.0      80.0
# ...                                ...      ...       ...
# 2058  Qualifies for reduced/free lunch     38.0      53.0
# 2067  Qualifies for reduced/free lunch     37.0      53.0
# 2070  Qualifies for reduced/free lunch     38.0      53.0
# 2080  Qualifies for reduced/free lunch     45.0      51.0
# 2128                  Does not qualify     39.0      55.0
#
# [79 rows x 9 columns]

# %%
# task 2 duplicate rows for school type, teaching method, pretest and posttest score

t2dup = data[data.duplicated(['school_type', 'pretest', 'posttest'], keep = False)]
t2dup
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender                             lunch  pretest  posttest
# 0     Female                  Does not qualify     62.0      72.0
# 1     Female                  Does not qualify     66.0      79.0
# 2       Male                  Does not qualify     64.0      76.0
# 3     Female                  Does not qualify     61.0      77.0
# 4       Male                  Does not qualify     64.0      76.0
# ...      ...                               ...      ...       ...
# 2128  Female                  Does not qualify     39.0      55.0
# 2129  Female  Qualifies for reduced/free lunch     38.0      46.0
# 2130  Female  Qualifies for reduced/free lunch     45.0      51.0
# 2131    Male  Qualifies for reduced/free lunch     46.0      53.0
# 2132    Male  Qualifies for reduced/free lunch     41.0      48.0
#
# [1597 rows x 10 columns]

# %%
# task 3 Average pretest scores of all schools

t3 = data.groupby(by = ['school'])[['pretest']].mean()
t3
# Out:
#           pretest
# school
# ANKYI   61.341463
# CCAAW   64.623853
# CIMBB   65.067568
# CUQAM   53.925234
# DNQDD   54.327869
# FBUMG   62.891304
# GJJHK   53.194915
# GOKXL   50.796875
# GOOBU   38.248408
# IDGFP   75.202128
# KFZMY   41.865385
# KZKKE   37.261261
# LAYPA   62.035088
# OJOBU   56.197531
# QOQTS   52.527027
# UAGPU   62.390805
# UKPGS   78.453125
# UUUQX   67.253012
# VHDHF   52.666667
# VKWQH   52.060000
# VVTVA   35.955752
# ZMNYA   68.130435
# ZOWMK   41.572650

# %%
# task 4 max and min males and females in each school setting


pd.crosstab(data.school_setting, [data.gender], values = data.student_id, aggfunc=['count'])
# Out:
#                 count
# gender         Female Male
# school_setting
# Rural             228  279
# Suburban          368  348
# Urban             456  444

# %%
# task 5 min and max postest scores of all schools

t5 = pd.pivot_table(data, index = ['school'], values = ['posttest'], aggfunc = ['min', 'max'])
t5
# Out:
#             min      max
#        posttest posttest
# school
# ANKYI      63.0     79.0
# CCAAW      67.0     91.0
# CIMBB      64.0     88.0
# CUQAM      56.0     76.0
# DNQDD      49.0     79.0
# FBUMG      68.0     88.0
# GJJHK      49.0     85.0
# GOKXL      48.0     77.0
# GOOBU      32.0     64.0
# IDGFP      74.0    100.0
# KFZMY      44.0     67.0
# KZKKE      36.0     62.0
# LAYPA      63.0     84.0
# OJOBU      50.0     84.0
# QOQTS      51.0     85.0
# UAGPU      62.0     83.0
# UKPGS      82.0     99.0
# UUUQX      62.0     91.0
# VHDHF      52.0     77.0
# VKWQH      48.0     82.0
# VVTVA      39.0     62.0
# ZMNYA      66.0     95.0
# ZOWMK      43.0     63.0

# %%
# task 5 part 2 top 5 schools in accordance to part 1

t5.head()
# Out:
#             min      max
#        posttest posttest
# school
# ANKYI      63.0     79.0
# CCAAW      67.0     91.0
# CIMBB      64.0     88.0
# CUQAM      56.0     76.0
# DNQDD      49.0     79.0

# %%
# task 6 part 1 sum and average of school wise pretest scores

t6 = pd.pivot_table(data ,index = ['school'], values = ['pretest'], aggfunc = ['mean','sum'])
t6
# Out:
#              mean      sum
#           pretest  pretest
# school
# ANKYI   61.341463   2515.0
# CCAAW   64.623853   7044.0
# CIMBB   65.067568   4815.0
# CUQAM   53.925234   5770.0
# DNQDD   54.327869   6628.0
# FBUMG   62.891304   2893.0
# GJJHK   53.194915   6277.0
# GOKXL   50.796875   3251.0
# GOOBU   38.248408   6005.0
# IDGFP   75.202128   7069.0
# KFZMY   41.865385   2177.0
# KZKKE   37.261261   4136.0
# LAYPA   62.035088   3536.0
# OJOBU   56.197531   4552.0
# QOQTS   52.527027   7774.0
# UAGPU   62.390805   5428.0
# UKPGS   78.453125  10042.0
# UUUQX   67.253012   5582.0
# VHDHF   52.666667   2686.0
# VKWQH   52.060000   5206.0
# VVTVA   35.955752   4063.0
# ZMNYA   68.130435   4701.0
# ZOWMK   41.572650   4864.0

# %%
# task 6 part 2 top 5 in accordance to task 6

t6.sort_values(('mean', 'pretest'), ascending = False).head()
# Out:
#              mean      sum
#           pretest  pretest
# school
# UKPGS   78.453125  10042.0
# IDGFP   75.202128   7069.0
# ZMNYA   68.130435   4701.0
# UUUQX   67.253012   5582.0
# CIMBB   65.067568   4815.0

# %%
# task 7 Assigning scholarships to FBUMG school students with 5LQ class type

t7 = data[(data.school == "FBUMG") & (data.classroom == "5LQ")]
t7.insert(9, "Scholarship", np.nan)
t7.loc[:,"Scholarship"] = t7.posttest * 100
t7
# Out:
#     school school_setting school_type classroom teaching_method student_id  \
# 467  FBUMG          Rural  Non-public       5LQ    Experimental      04DG5
# 468  FBUMG          Rural  Non-public       5LQ    Experimental      20M2D
# 469  FBUMG          Rural  Non-public       5LQ    Experimental      39KCW
# 470  FBUMG          Rural  Non-public       5LQ    Experimental      5Z1B6
# 471  FBUMG          Rural  Non-public       5LQ    Experimental      6TLU8
# 472  FBUMG          Rural  Non-public       5LQ    Experimental      ATQQJ
# 473  FBUMG          Rural  Non-public       5LQ    Experimental      AYEU1
# 474  FBUMG          Rural  Non-public       5LQ    Experimental      B9FSU
# 475  FBUMG          Rural  Non-public       5LQ    Experimental      EV13K
# 476  FBUMG          Rural  Non-public       5LQ    Experimental      I5H37
# 477  FBUMG          Rural  Non-public       5LQ    Experimental      JC5I9
# 478  FBUMG          Rural  Non-public       5LQ    Experimental      JPE2J
# 479  FBUMG          Rural  Non-public       5LQ    Experimental      MFBYU
# 480  FBUMG          Rural  Non-public       5LQ    Experimental      O144X
# 481  FBUMG          Rural  Non-public       5LQ    Experimental      OGKP3
# 482  FBUMG          Rural  Non-public       5LQ    Experimental      UMFI7
# 483  FBUMG          Rural  Non-public       5LQ    Experimental      V1DNJ
# 484  FBUMG          Rural  Non-public       5LQ    Experimental      YRN9S
#
#      gender                             lunch  pretest  Scholarship  posttest
# 467  Female  Qualifies for reduced/free lunch     63.0       8400.0      84.0
# 468  Female  Qualifies for reduced/free lunch     68.0       8500.0      85.0
# 469    Male  Qualifies for reduced/free lunch     66.0       8100.0      81.0
# 470    Male                  Does not qualify     68.0       8800.0      88.0
# 471  Female                  Does not qualify     66.0       8100.0      81.0
# 472  Female                  Does not qualify     68.0       8200.0      82.0
# 473    Male  Qualifies for reduced/free lunch     68.0       7900.0      79.0
# 474    Male                  Does not qualify     69.0       8300.0      83.0
# 475  Female                  Does not qualify     66.0       8300.0      83.0
# 476    Male  Qualifies for reduced/free lunch     65.0       8300.0      83.0
# 477     NaN                  Does not qualify     58.0       8000.0      80.0
# 478    Male                  Does not qualify     59.0       8100.0      81.0
# 479  Female                  Does not qualify     73.0       8200.0      82.0
# 480    Male                  Does not qualify     67.0       8600.0      86.0
# 481    Male                  Does not qualify     72.0       8300.0      83.0
# 482  Female  Qualifies for reduced/free lunch     56.0       7300.0      73.0
# 483    Male                  Does not qualify     61.0       7600.0      76.0
# 484    Male                  Does not qualify     68.0       8700.0      87.0

# %%
# task 8 Replace the values with Yes and NO

t8 = data.replace(['Does not qualify', 'Qualifies for reduced/free lunch'], ['No','Yes'])
t8
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender lunch  pretest  posttest
# 0     Female    No     62.0      72.0
# 1     Female    No     66.0      79.0
# 2       Male    No     64.0      76.0
# 3     Female    No     61.0      77.0
# 4       Male    No     64.0      76.0
# ...      ...   ...      ...       ...
# 2128  Female    No     39.0      55.0
# 2129  Female   Yes     38.0      46.0
# 2130  Female   Yes     45.0      51.0
# 2131    Male   Yes     46.0      53.0
# 2132    Male   Yes     41.0      48.0
#
# [2133 rows x 10 columns]

# %%
# task 9 Count of different teaching methods by location

t9 = pd.crosstab(data.school_setting, data.teaching_method)  # by default cross table gives output count
t9
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     201       309
# Suburban                  284       433
# Urban                     275       631

# %%
# task 10 replacing pretest scores of students with 135 where it's 39.

t10 = data[(data.gender=="Male") & (data.posttest<39)]
t10.iloc[0:,8] = 135
t10
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 742   GOOBU          Urban      Public       HKF        Standard      8BONX
# 745   GOOBU          Urban      Public       HKF        Standard      ESWTA
# 751   GOOBU          Urban      Public       HKF        Standard      LTIOX
# 1023  KZKKE          Rural      Public       3D0        Standard      RHOL5
# 1081  KZKKE          Rural      Public       QTU        Standard      CRILM
# 1089  KZKKE          Rural      Public       QTU        Standard      QM9VS
#
#      gender                             lunch  pretest  posttest
# 742    Male  Qualifies for reduced/free lunch    135.0      38.0
# 745    Male  Qualifies for reduced/free lunch    135.0      38.0
# 751    Male  Qualifies for reduced/free lunch    135.0      34.0
# 1023   Male  Qualifies for reduced/free lunch    135.0      37.0
# 1081   Male  Qualifies for reduced/free lunch    135.0      38.0
# 1089   Male  Qualifies for reduced/free lunch    135.0      37.0

# %%
# task 11 Average posttest score for urban and suburban male students with relative percentage
 
t11 = data[(data.school_setting == 'Urban') & (data.gender == 'Male') | (data.school_setting == 'Suburban') & (data.gender == 'Male')]
t11a = t11.groupby(by=['school_setting', 'gender'])[['posttest']].mean()
percDiff = (75.942529 - 62.421171) * 100 / 75.942529         # values taken from output of t11
print(percDiff)
t11a
# Out:
# 17.804724412061642
#                         posttest
# school_setting gender
# Suburban       Male    75.942529
# Urban          Male    62.421171

# %%
# task 12 part 1 find total missing values and replace them with appropriate values

data.isnull().sum()
# Out:
# school              0
# school_setting      0
# school_type         0
# classroom           0
# teaching_method     0
# student_id          0
# gender             10
# lunch               0
# pretest             4
# posttest            4
# dtype: int64

# %%
# task 12 part 2

data.gender.value_counts()
# Out:
# Male      1071
# Female    1052
# Name: gender, dtype: int64

# %%
# task 12 part 3

data.gender = data.gender.fillna('Male')
t12a = data.pretest.mean()  
t12b = data.posttest.mean()
print(t12a, 'Is pretest average')
print(t12b, 'Is posttest average')

data.pretest = data.pretest.fillna(t12a)
data.posttest = data.posttest.fillna(t12b)

data.isnull().sum()
# Out:
# 54.96195396899953 Is pretest average
# 67.11131986848285 Is posttest average
# school             0
# school_setting     0
# school_type        0
# classroom          0
# teaching_method    0
# student_id         0
# gender             0
# lunch              0
# pretest            0
# posttest           0
# dtype: int64
