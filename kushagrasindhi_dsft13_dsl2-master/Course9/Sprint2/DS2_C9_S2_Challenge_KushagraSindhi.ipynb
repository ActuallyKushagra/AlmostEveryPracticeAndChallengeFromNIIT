# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_regression
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

# %%
# task 1

x,y = make_regression(n_samples =100, n_features = 1, noise = 4, bias = 100)

# %%
x.ndim , y.ndim
# Out:
# (2, 1)

# %%
x.shape , y.shape
# Out:
# ((100, 1), (100,))

# %%
plt.scatter(x,y);
plt.title('Toy dataset');
plt.xlabel('X axis');
plt.ylabel('Y axis');

# %%
x_train , x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
lr_model = LinearRegression().fit(x_train,y_train)

# %%
lr_model.score(x_train,y_train)
# Out:
# 0.9904433960304577

# %%
y_pred = lr_model.predict(x_test)
y_pred
# Out:
# array([ 51.15772222,  52.79364372,  42.0830366 , 121.75464271,
#         94.32776251, 116.14528301,  56.49487642, 108.79560333,
#         85.15761503,  41.09071877,  78.58844688,  91.96104159,
#        115.84906669, 128.06719763,  72.0611297 ,  46.86089588,
#        115.52298669, 109.3242706 ,  43.12476276, 115.0275369 ,
#         80.16121863, 182.4059953 , 123.48529116,  87.91319742,
#        127.29528883,  97.91607262, 110.29230025,  72.68473698,
#         88.6585388 ,  63.34616866])

# %%
lr_model.intercept_
# Out:
# 100.64305086176745

# %%
lr_model.coef_
# Out:
# array([35.24780795])

# %%
mse = mean_squared_error(y_test , y_pred)
mae = mean_absolute_error(y_test , y_pred)
RMSE = mean_squared_error(y_test, y_pred, squared=False)
R2_val = r2_score(y_test , y_pred)
print(f"""MSE : {mse}
MAE : {mae}
RMSE : {RMSE}
R2 : {R2_val}""")
# Out:
# MSE : 11.843985498777721
# MAE : 2.7410956184206983
# RMSE : 3.441509189117141
# R2 : 0.9883548676331084

# %%
# task 2

x , y = make_regression(n_samples =100, n_features = 1, noise = 200, bias = 100)

# %%
plt.scatter(x,y);

# %%
x_train , x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
lr_model = LinearRegression().fit(x_train,y_train)

# %%
lr_model.score(x_train,y_train)

# %%
y_pred = lr_model.predict(x_test)
y_pred
# Out:
# array([ 86.34730212,  83.28642104,  84.56269763,  95.0366032 ,
#         94.43990926,  99.85995469,  91.65626575,  99.44860194,
#         85.9769011 ,  83.01810018,  83.62898497,  85.20011761,
#         82.80938342, 102.06595883,  81.61263361,  80.09621992,
#         74.16693899,  89.34163663,  80.20075715,  85.53911769,
#         71.48089482,  94.30201902,  82.48949275,  93.50228677,
#         76.68245586,  82.46242114,  88.29370005,  89.80864899,
#         83.4705123 , 110.25465774])

# %%
lr_model.intercept_
# Out:
# 88.46338985747174

# %%
lr_model.coef_
# Out:
# array([9.88944323])

# %%
mse = mean_squared_error(y_test , y_pred)
mae = mean_absolute_error(y_test , y_pred)
RMSE = mean_squared_error(y_test, y_pred, squared=False)
R2_val = r2_score(y_test , y_pred)
print(f"""MSE : {mse}
MAE : {mae}
RMSE : {RMSE}
R2 : {R2_val}""")
# Out:
# MSE : 64789.47449541544
# MAE : 219.8240859569119
# RMSE : 254.5377663440446
# R2 : -0.020923293684234512

# %%
# task 3
# a
df = pd.read_csv('DS2_C5_S2_Communities_Data_Challenge.data')
df
# Out:
#        8   ?    ?.1         Lakewoodcity   1  0.19  0.33  0.02   0.9  0.12  \
# 0     53   ?      ?          Tukwilacity   1  0.00  0.16  0.12  0.74  0.45
# 1     24   ?      ?         Aberdeentown   1  0.00  0.42  0.49  0.56  0.17
# 2     34   5  81440  Willingborotownship   1  0.04  0.77  1.00  0.08  0.12
# 3     42  95   6096    Bethlehemtownship   1  0.01  0.55  0.02  0.95  0.09
# 4      6   ?      ?    SouthPasadenacity   1  0.02  0.28  0.06  0.54  1.00
# ...   ..  ..    ...                  ...  ..   ...   ...   ...   ...   ...
# 1988  12   ?      ?    TempleTerracecity  10  0.01  0.40  0.10  0.87  0.12
# 1989   6   ?      ?          Seasidecity  10  0.05  0.96  0.46  0.28  0.83
# 1990   9   9  80070        Waterburytown  10  0.16  0.37  0.25  0.69  0.04
# 1991  25  17  72600          Walthamcity  10  0.08  0.51  0.06  0.87  0.22
# 1992   6   ?      ?          Ontariocity  10  0.20  0.78  0.14  0.46  0.24
#
# ...

# %%
# b
df.drop(df.columns[0:5], axis = 1,inplace = True)
df
# Out:
#       0.19  0.33  0.02   0.9  0.12  0.17  0.34  0.47  0.29  0.32  ...  0.12.2  \
# 0     0.00  0.16  0.12  0.74  0.45  0.07  0.26  0.59  0.35  0.27  ...    0.02
# 1     0.00  0.42  0.49  0.56  0.17  0.04  0.39  0.47  0.28  0.32  ...    0.01
# 2     0.04  0.77  1.00  0.08  0.12  0.10  0.51  0.50  0.34  0.21  ...    0.02
# 3     0.01  0.55  0.02  0.95  0.09  0.05  0.38  0.38  0.23  0.36  ...    0.04
# 4     0.02  0.28  0.06  0.54  1.00  0.25  0.31  0.48  0.27  0.37  ...    0.01
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...     ...
# 1988  0.01  0.40  0.10  0.87  0.12  0.16  0.43  0.51  0.35  0.30  ...    0.01
# 1989  0.05  0.96  0.46  0.28  0.83  0.32  0.69  0.86  0.73  0.14  ...    0.02
# 1990  0.16  0.37  0.25  0.69  0.04  0.25  0.35  0.50  0.31  0.54  ...    0.08
# 1991  0.08  0.51  0.06  0.87  0.22  0.10  0.58  0.74  0.63  0.41  ...    0.03
# 1992  0.20  0.78  0.14  0.46  0.24  0.77  0.50  0.62  0.40  0.17  ...    0.11
#
# ...

# %%
# c
df.replace('?',np.nan, inplace = True)
df.dropna(axis = 1, inplace = True)
df
# Out:
#       0.19  0.33  0.02   0.9  0.12  0.17  0.34  0.47  0.29  0.32  ...  0.12.1  \
# 0     0.00  0.16  0.12  0.74  0.45  0.07  0.26  0.59  0.35  0.27  ...    0.21
# 1     0.00  0.42  0.49  0.56  0.17  0.04  0.39  0.47  0.28  0.32  ...    0.14
# 2     0.04  0.77  1.00  0.08  0.12  0.10  0.51  0.50  0.34  0.21  ...    0.19
# 3     0.01  0.55  0.02  0.95  0.09  0.05  0.38  0.38  0.23  0.36  ...    0.11
# 4     0.02  0.28  0.06  0.54  1.00  0.25  0.31  0.48  0.27  0.37  ...    0.70
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...     ...
# 1988  0.01  0.40  0.10  0.87  0.12  0.16  0.43  0.51  0.35  0.30  ...    0.22
# 1989  0.05  0.96  0.46  0.28  0.83  0.32  0.69  0.86  0.73  0.14  ...    0.53
# 1990  0.16  0.37  0.25  0.69  0.04  0.25  0.35  0.50  0.31  0.54  ...    0.25
# 1991  0.08  0.51  0.06  0.87  0.22  0.10  0.58  0.74  0.63  0.41  ...    0.45
# 1992  0.20  0.78  0.14  0.46  0.24  0.77  0.50  0.62  0.40  0.17  ...    0.68
#
# ...

# %%
# d
y = df['0.2.2']
x = df.iloc[:,:-1].values.reshape((-1,99))
x_train ,x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 1)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train , y_train)
# Out:
# 0.7180561716263607

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([ 0.02728222,  0.22926161,  0.24358117,  0.06115535,  0.0217067 ,
#         0.03401063,  0.27552699,  0.11858311,  0.36258362,  0.15377255,
#         0.09813233,  0.04472432,  0.12354792,  0.01617531,  0.52868503,
#         0.01510004, -0.02767431,  0.40703087,  0.55664427,  0.15680863,
#         0.3810561 ,  0.17288593,  0.31623453,  0.04474817,  0.39253993,
#         0.2307003 ,  0.0714214 ,  0.54480421,  0.09330472,  0.62447953,
#         0.00492088,  0.20191649,  0.38229442,  0.14432642,  0.02874211,
#         0.21433982,  0.3706728 ,  0.40329487, -0.02359003,  0.32438831,
#         0.5226272 ,  0.12572197,  0.01007901,  0.23012896,  0.12594249,
#         0.26896015,  0.22802976,  0.76654151,  0.00364849,  0.04221629,
#         0.72539712,  0.12973228,  0.5662074 ,  0.2788974 ,  0.06331061,
#         0.10309141,  0.32362989,  0.04977497,  0.40022068,  0.02746098,
#         0.33887421,  0.56575035,  0.15969295,  0.09760788,  0.05220292,
# ...

# %%
lr.intercept_
# Out:
# 0.5150592172040629

# %%
lr.coef_
# Out:
# array([ 1.19036872e-01,  5.45041348e-02,  1.78543640e-01, -1.09415219e-01,
#        -2.48677704e-02,  6.27840891e-02,  1.72882504e-01, -3.64163716e-01,
#        -3.68332699e-02,  6.27650903e-02, -1.47302176e-01,  3.82112688e-02,
#         5.45209418e-02, -1.71673720e-01,  3.07115419e-02, -1.44722598e-01,
#         9.83903109e-02,  3.20253756e-02, -6.17403053e-02, -4.82519163e-02,
#         2.81671584e-01, -4.79106652e-01, -3.54314444e-02, -1.48012386e-02,
#         5.14275732e-02,  3.54777402e-02,  1.35338621e-01, -1.63237013e-01,
#         8.11445183e-03, -1.53969852e-02,  8.02172553e-03,  1.53909760e-02,
#         3.90930439e-01, -7.43432253e-02, -7.40223976e-02,  7.57262205e-02,
#         2.10624467e-01,  2.14809931e-01,  2.24427321e-01, -2.00482159e-02,
#        -1.67941266e-01, -1.10007122e-01,  1.10949705e-01, -4.14225581e-01,
#        -4.05738364e-02,  2.78178237e-02,  4.76078525e-02, -2.15824491e-01,
# ...

# %%
RMSE = mean_squared_error(y_test , y_pred, squared =False)
R2_val = r2_score(y_test , y_pred)

print(f"""RMSE : {RMSE}
R2 : {R2_val}""")
# Out:
# RMSE : 0.14318592902676996
# R2 : 0.583336552209295

# %%
fig , axes = plt.subplots(20,5,figsize=(25,45))
for col , ax in zip(df.columns,axes.flatten()):
    if col != '0.2.2':
        sns.regplot(x = col, y = df['0.2.2'],data = df,ax = ax);
        ax.set_title(col)
