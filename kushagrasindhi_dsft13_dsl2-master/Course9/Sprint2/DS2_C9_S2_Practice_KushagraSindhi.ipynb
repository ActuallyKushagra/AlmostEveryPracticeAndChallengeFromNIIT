# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

# %%
# task 1

df = pd.read_csv('DS2_C5_S2_Mtcars_Data_Practice.csv')
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
# b)

df.isnull().sum()
# Out:
# Unnamed: 0    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder()
df['Unnamed: 0'] = label_encoder.fit_transform(df['Unnamed: 0'])

# %%
scale = MinMaxScaler()
df_scaled = pd.DataFrame(scale.fit_transform(df) , columns = df.columns)
df_scaled
# Out:
#     Unnamed: 0       mpg  cyl      disp        hp      drat        wt  \
# 0     0.548387  0.451064  0.5  0.221751  0.204947  0.525346  0.283048
# 1     0.580645  0.451064  0.5  0.221751  0.204947  0.525346  0.348249
# 2     0.129032  0.527660  0.0  0.092043  0.144876  0.502304  0.206341
# 3     0.387097  0.468085  0.5  0.466201  0.204947  0.147465  0.435183
# 4     0.419355  0.353191  1.0  0.720629  0.434629  0.179724  0.492713
# 5     0.967742  0.327660  0.5  0.383886  0.187279  0.000000  0.497827
# 6     0.193548  0.165957  1.0  0.720629  0.681979  0.207373  0.525952
# 7     0.645161  0.595745  0.0  0.188576  0.035336  0.428571  0.428791
# 8     0.612903  0.527660  0.0  0.173859  0.151943  0.534562  0.418563
# 9     0.677419  0.374468  0.5  0.240708  0.250883  0.534562  0.492713
# 10    0.709677  0.314894  0.5  0.240708  0.250883  0.534562  0.492713
# 11    0.741935  0.255319  1.0  0.510601  0.452297  0.142857  0.653797
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df_scaled.corr() , annot = True);

# %%
y = np.array(df_scaled['mpg']).reshape((-1,1))
x = np.array(df_scaled['wt']).reshape((-1,1))
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state = 42)

# %%
# c

sns.pairplot(df);

# %%
# task 2

lr_model = LinearRegression()
lr_model.fit(x_train , y_train)
lr_model.score(x_train , y_train)
R2_1 = r2_score(y_test , y_pred)
print('intercept is ',lr_model.intercept_)
print('slope is ', lr_model.coef_)
print('r^2 is ', R2_1)
# Out:
# intercept is  [0.78893812]
# slope is  [[-0.89139953]]
# r^2 is  0.7325617144205855

# %%
y_pred = lr_model.predict(x_test)

# %%
MSE=mean_squared_error(y_test, y_pred)
MAE=mean_absolute_error(y_test,y_pred)
RMSE = mean_squared_error(y_test, y_pred, squared=False)
print(MSE, MAE, RMSE)
# Out:
# 0.01645845960621193 0.1012875094901382 0.12829052812352099

# %%
fig, ax = plt.subplots()
ax.set_xlabel('xlabel', fontsize=12)
ax.set_ylabel('ylabel', fontsize=12)
plt.ylim((0,30))
df.plot.scatter(x = 'wt', y = 'mpg', s = 30, ax=ax)
plt.plot(x_test, y_pred, color="blue", linewidth=2)

# %%
# task 3


X_2 = df['wt'].values.reshape(-1,2)
Y = df['mpg']
x = X_2[:, 0]
y = X_2[:, 1]
z = Y

# %%
X3=df[['wt','mpg']].values.reshape(-1,2)
z3=np.array(z)
X_train,X_test,z_train,z_test=train_test_split(X3,z3,test_size=0.3,random_state=1)

# %%
model_mul = LinearRegression().fit(X_train, z_train)

# %%
print('Intercept:', model_mul.intercept_)
print('Coefficients:', model_mul.coef_)
r_sq2 = model_mul.score(X_train,z_train)
print('r^2:', r_sq2)
# Out:
# Intercept: -1.0658141036401503e-14
# Coefficients: [1.6915838e-15 1.0000000e+00]
# r^2: 1.0

# %%
MSE=mean_squared_error(z_test, model_mul.predict(X_test))
RMSE = mean_squared_error(z_test, model_mul.predict(X_test), squared=False)
print(MSE, RMSE)
# Out:
# 1.1044052673094165e-29 3.3232593448441795e-15

# %%
# task 4

X3=df[['mpg','cyl','disp']].values.reshape(-1,3)
z3=np.array(z)
X_train,X_test,z_train,z_test=train_test_split(X3,z3,test_size=0.3,random_state=200)

# %%
model_mul = LinearRegression().fit(X_train, z_train)

# %%
print('Intercept: ', model_mul.intercept_)
print('Coefficients: ', model_mul.coef_)
r_sq2 = model_mul.score(X_train,z_train)
print('coefficient of determination:', r_sq2)
# Out:
# Intercept:  -1.4210854715202004e-14
# Coefficients:  [1.00000000e+00 5.82270766e-16 2.69157967e-17]
# coefficient of determination: 1.0

# %%
MSE=mean_squared_error(z_test, model_mul.predict(X_test))
RMSE = mean_squared_error(z_test, model_mul.predict(X_test), squared=False)
print(MSE, RMSE)
# Out:
# 1.388395193188981e-29 3.7261175413410954e-15
